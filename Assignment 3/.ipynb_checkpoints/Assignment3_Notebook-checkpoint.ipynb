# %% [markdown]
# * Brian O'Connell
# * <span style="background-color:#33FFF5">brr99@pitt.edu</span>
# ---

# %% [markdown]
# # Assignment 3
# ## Worldbank Data exploration

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
# visualization and tuning the aesthetics
import sys
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})
plt.style.use('seaborn-whitegrid')
plt.rc('text', usetex = False)
plt.rc('font', family = 'serif')
plt.rc('xtick', labelsize = 10) 
plt.rc('ytick', labelsize = 10) 
plt.rc('font', size = 12) 
plt.rc('figure', figsize = (6, 5))

# %% [markdown]
# ### Initial Data upload and descrition

# %%
WB = pd.read_csv('WorldBank_Assignment3_Data.csv')

# %%
WB.describe()
# Out:
#        2015 [YR2015]
# count     132.000000
# mean    23208.978659
# std     96054.088925
# min         0.000000
# 25%        19.993992
# 50%        40.555518
# 75%        95.468750
# max    847460.000000

# %%
WB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   134 non-null    object
#  1   Country Code   132 non-null    object
#  2   Series Name    132 non-null    object
#  3   Series Code    132 non-null    object
#  4   2015 [YR2015]  132 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 5.5+ KB

# %% [markdown]
# As seen from above the dataset was downloaded and has the year as a column and all of the variables are in  the seires name coulumn, I need to convert to long format and did this by using the pivot_table function to organize the variables.

# %%
WB.pivot = WB.pivot_table(index='Country Name', 
                         columns='Series Name', 
                         values='2015 [YR2015]')

# %% [markdown]
# Upon inspecting the data the only missing data was in Bulgaria, Croatia, and Cyprus for the % alternative energy use variable and this is because they were not using any of these methods for electricity production so these countries were given values of 0 for that variable.

# %%
WB.pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, Austria to Sweden
# Data columns (total 6 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Alternative and nuclear energy (% of total energy use)              22 non-null     float64
#  1   Electricity production from oil, gas and coal sources (% of total)  22 non-null     float64
#  2   Forest area (% of land area)                                        22 non-null     float64
#  3   Proportion of seats held by women in national parliaments (%)       22 non-null     float64
#  4   Total greenhouse gas emissions (kt of CO2 equivalent)               22 non-null     float64
#  5   Women Business and the Law Index Score (scale 1-100)                22 non-null     float64
# dtypes: float64(6)
# memory usage: 1.2+ KB

# %%
WB.pivot
# Out:
# Series Name      Alternative and nuclear energy (% of total energy use)  \
# Country Name
# Austria                                                  12.212879
# Belgium                                                  15.110327
# Bulgaria                                                  0.000000
# Croatia                                                   0.000000
# Cyprus                                                    0.000000
# Czech Republic                                           18.956573
# Denmark                                                  11.748946
# Estonia                                                   0.933237
# Finland                                                  25.351314
# France                                                   49.061541
# Germany                                                  12.863620
# Greece                                                    6.202481
# Hungary                                                  18.451463
# Ireland                                                   4.800149
# Italy                                                     6.327221
# Latvia                                                    0.000000
# Luxembourg                                                3.713095
# Netherlands                                               3.373805
# Slovak Republic                                          27.467792
# Slovenia                                                 28.225848
# Spain                                                    19.975377
# Sweden                                                   43.241150
#
# Series Name      Electricity production from oil, gas and coal sources (% of total)  \
# Country Name
# Austria                                                  22.222042
# Belgium                                                  39.214643
# France                                                     100.000
# Germany                                                     94.375
# Greece                                                      97.500
# Hungary                                                     96.875
# Ireland                                                     95.000
# Italy                                                       94.375
# Latvia                                                     100.000
# Luxembourg                                                 100.000
# Netherlands                                                 97.500
# Slovak Republic                                             94.375
# Slovenia                                                    90.625
# Spain                                                       97.500
# Sweden                                                     100.000

# %%
WB.pivot.describe()
# Out:
# Series Name  Alternative and nuclear energy (% of total energy use)  \
# count                                                22.000000
# mean                                                 14.000764
# std                                                  13.914065
# min                                                   0.000000
# 25%                                                   3.458627
# 50%                                                  11.980913
# 75%                                                  19.720676
# max                                                  49.061541
#
# Series Name  Electricity production from oil, gas and coal sources (% of total)  \
# count                                                22.000000
# mean                                                 42.342345
# std                                                  24.506647
# min                                                   1.085030
# 25%                                                  24.641451
# 50%                                                  41.640893
# 75%                                                  59.163904
# max                                                  91.219943
#
# Series Name  Forest area (% of land area)  \
# count                           22.000000
# mean                            36.633331
# std                             17.536510
# min                             10.835462
# 25%                             24.640651
# 50%                             34.261879
# 75%                             45.267039
# max                             73.735645
#
# Series Name  Proportion of seats held by women in national parliaments (%)  \
# count                                                22.000000
# mean                                                 27.458015
# std                                                  10.505644
# min                                                  10.101010
# 25%                                                  18.916667
# 50%                                                  27.251589
# 75%                                                  37.166667
# max                                                  43.553009
#
# Series Name  Total greenhouse gas emissions (kt of CO2 equivalent)  \
# count                                                22.000000
# mean                                             139037.727273
# std                                              201714.841462
# min                                                8140.000000
# 25%                                               26460.000000
# 50%                                               57820.000000
# 75%                                              119597.500000
# max                                              847460.000000
#
# Series Name  Women Business and the Law Index Score (scale 1-100)
# count                                                22.000000
# mean                                                 95.710227
# std                                                   3.625387
# min                                                  88.750000
# 25%                                                  93.906250
# 50%                                                  95.937500
# 75%                                                  99.375000
# max                                                 100.000000

# %%
WB.pivot.rename(columns = {'Alternative and nuclear energy (% of total energy use)':'Alternative energy use %','Electricity production from oil, gas and coal sources (% of total)':'Electricity from oil, gas and coal sources %' ,'Proportion of seats held by women in national parliaments (%)':'Proportion of seats held by women in parliament', 'Total greenhouse gas emissions (kt of CO2 equivalent)':'Total greenhouse gas emissions', 'Women Business and the Law Index Score (scale 1-100)':'Women Business and the Law Index Score'}, inplace = True)

x_var= ['Alternative energy use %', 'Electricity from oil, gas and coal sources %', 'Forest area (% of land area)','Proportion of seats held by women in parliament','Women Business and the Law Index Score']
sns.pairplot(data=WB.pivot, y_vars=['Total greenhouse gas emissions'], x_vars=x_var, height=4.5)

# %% [markdown]
# The high total greenhouse gas emissions in each of the graphs is Germany, this is potentially an issue since all of the other countries are clustered much lower comparitively. This is likely due to the population difference between Germany and these other countries.

# %%
WB.pivot.corr()
# Out:
# Series Name                                      Alternative energy use %  \
# Series Name
# Alternative energy use %                                         1.000000
# Electricity from oil, gas and coal sources %                    -0.645341
# Forest area (% of land area)                                     0.373138
# Proportion of seats held by women in parliament                  0.398327
# Total greenhouse gas emissions                                   0.193812
# Women Business and the Law Index Score                           0.313972
#
# Series Name                                      Electricity from oil, gas and coal sources %  \
# Series Name
# Alternative energy use %                                                            -0.645341
# Electricity from oil, gas and coal sources %                                         1.000000
# Forest area (% of land area)                                                        -0.617964
# Proportion of seats held by women in parliament                                     -0.285233
# Total greenhouse gas emissions                                                       0.089903
# Women Business and the Law Index Score                                              -0.222031
#
# Series Name                                      Forest area (% of land area)  \
# Series Name
# Alternative energy use %                                             0.373138
# Electricity from oil, gas and coal sources %                        -0.617964
# Forest area (% of land area)                                         1.000000
# Proportion of seats held by women in parliament                      0.328934
# Total greenhouse gas emissions                                      -0.178109
# Women Business and the Law Index Score                              -0.017550
#
# Series Name                                      Proportion of seats held by women in parliament  \
# Series Name
# Alternative energy use %                                                                0.398327
# Electricity from oil, gas and coal sources %                                           -0.285233
# Forest area (% of land area)                                                            0.328934
# Proportion of seats held by women in parliament                                         1.000000
# Total greenhouse gas emissions                                                          0.313395
# Women Business and the Law Index Score                                                  0.399063
#
# Series Name                                      Total greenhouse gas emissions  \
# Series Name
# Alternative energy use %                                               0.193812
# Electricity from oil, gas and coal sources %                           0.089903
# Forest area (% of land area)                                          -0.178109
# Proportion of seats held by women in parliament                        0.313395
# Total greenhouse gas emissions                                         1.000000
# Women Business and the Law Index Score                                 0.070769
#
# Series Name                                      Women Business and the Law Index Score
# Series Name
# Alternative energy use %                                                       0.313972
# Electricity from oil, gas and coal sources %                                  -0.222031
# Forest area (% of land area)                                                  -0.017550
# Proportion of seats held by women in parliament                                0.399063
# Total greenhouse gas emissions                                                 0.070769
# Women Business and the Law Index Score                                         1.000000

# %%
corrmat = WB.pivot.corr()
sns.heatmap(corrmat, square = True, cmap="PuBu")
# Out:
# <AxesSubplot:xlabel='Series Name', ylabel='Series Name'>

# %% [markdown]
# Some of the variables have some higher correlatioons based on the table and plot above.

# %% [markdown]
# There are 5 input varaibles so that gives us $5 \choose 2$ = 10 combinations of scatter plots.

# %%
sns.lmplot(x="Alternative energy use %", y="Electricity from oil, gas and coal sources %", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Alternative energy use %", y="Forest area (% of land area)", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Alternative energy use %", y="Proportion of seats held by women in parliament", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Women Business and the Law Index Score", y="Alternative energy use %", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Electricity from oil, gas and coal sources %", y="Forest area (% of land area)", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Electricity from oil, gas and coal sources %", y="Proportion of seats held by women in parliament", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Women Business and the Law Index Score", y="Electricity from oil, gas and coal sources %", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Women Business and the Law Index Score", y="Proportion of seats held by women in parliament", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Women Business and the Law Index Score", y="Forest area (% of land area)", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})

# %%
sns.lmplot(x="Forest area (% of land area)", y="Proportion of seats held by women in parliament", data=WB.pivot, order=1, ci=95, scatter_kws={'color':'b'}, line_kws={'color':'r'})
