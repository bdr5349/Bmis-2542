# %% [markdown]
# # Exercise-1

# %% [markdown]
# * Brian O'Connell
# * <span style="background-color:#33FFF5">brr99@pitt.edu</span>
# ---

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
anscombe = pd.read_csv('anscombe.csv')

# %%
anscombe.columns
# Out:
# Index(['x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'x4', 'y4'], dtype='object')

# %%
anscombe.isna().sum()
# Out:
# x1    0
# y1    0
# x2    0
# y2    0
# x3    0
# y3    0
# x4    0
# y4    0
# dtype: int64

# %%
anscombe.describe()
# Out:
#               x1         y1         x2         y2         x3         y3  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#               x4         y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
plt.scatter(x='x1', y='y1', data=anscombe, color = 'blue', marker='x')

# %%
plt.scatter(x='x2', y='y2', data=anscombe, color = 'blue', marker='x')

# %%
plt.scatter(x='x3', y='y3', data=anscombe, color = 'blue', marker='x')

# %%
plt.scatter(x='x4', y='y4', data=anscombe, color = 'blue', marker='x')

# %%
sns.relplot(x="x1", y="y1", data=anscombe, kind="scatter")

# %%
sns.relplot(x="x2", y="y2", data=anscombe, kind="scatter")

# %%
sns.relplot(x="x3", y="y3", data=anscombe, kind="scatter")

# %%
sns.relplot(x="x4", y="y4", data=anscombe, kind="scatter")

# %%
sns.relplot(x="x1", y="y1", data=anscombe)

# %%
sns.pairplot(anscombe)
